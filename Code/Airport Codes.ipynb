# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')

# %%
url = "https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic"
browser.visit(url)

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
table = soup.find('table', class_='wikitable sortable jquery-tablesorter')

# %%
# Create an empty list
Airports = []
rows = table.find_all('tr', class_=False)
# Loop through the scraped data to create a list of rows
for row in rows:
    row_data_id = row.find_all('td')
    row = [row.text for row in row_data_id]
    Airports.append(row)

# %%
Airports
# Out:
# [[],
#  ['1.',
#   ' Hartsfield–Jackson Atlanta International Airport',
#   'Atlanta, Georgia',
#   'United States',
#   'ATL/KATL',
#   '104,653,451',
#   '',
#   '11.7%\n'],
#  ['2.',
#   ' Dubai International Airport',
#   'Garhoud, Dubai, Dubai',
#   'United Arab Emirates',
#   'DXB/OMDB',
#   '86,994,365',
#   '3',
#   '31.7%\n'],
#  ['3.',
#   ' Dallas Fort Worth International Airport',
#   'Dallas–Fort Worth, Texas',
#   'United States',
#   'DFW/KDFW',
#   '81,755,538',
#   '1',
#   '11.4%\n'],
#  ['4.',
#   ' Heathrow Airport',
#   'Hillingdon, London',
#   'United Kingdom',
#   'LHR/EGLL',
#   '79,183,364',
#   '4',
#   '28.5%\n'],
#  ['5.',
#   ' Tokyo Haneda Airport',
#   'Ōta, Tokyo',
#   'Japan',
#   'HND/RJTT',
#   '78,719,302',
#   '11',
#   '55.1%\n'],
#  ['6.',
#   ' Denver International Airport',
#   'Denver, Colorado',
#   'United States',
#   'DEN/KDEN',
#   '77,837,917',
#   '3',
#   '12.3%\n'],
#  ['7.',
#   ' Istanbul Airport',
#   'Arnavutköy, Istanbul',
# ...

# %%
Airports_df = pd.DataFrame(Airports, columns = ["Rank", "Airport", "Location", "Country", "A/P Code", "Total Passengers", "Rank Change", "Rank pct change"])

# %%
Airports_df = Airports_df.drop(columns=["Rank Change", "Rank pct change"])

# %%
Airports_df = Airports_df.dropna()

# %%
#split the Airport code from the ICAO Code.
# Airports_df[['A/P Code', 'ICAO Code']] = Airports_df['A/P Code'].str.split('/', expand=True)

# %%
airport_codes_df = Airports_df['A/P Code'].tolist()

# %%
airport_codes_df
# Out:
# ['ATL',
#  'DXB',
#  'DFW',
#  'LHR',
#  'HND',
#  'DEN',
#  'IST',
#  'LAX',
#  'ORD',
#  'DEL',
#  'CDG',
#  'CAN',
#  'JFK',
#  'AMS',
#  'MAD',
#  'FRA',
#  'SIN',
#  'MCO',
#  'LAS',
#  'ICN',
#  'PVG',
#  'CLT',
#  'PEK',
#  'SZX',
#  'MIA',
#  'BKK',
#  'BOM',
#  'SEA',
#  'SFO',
#  'BCN',
#  'EWR',
#  'CGK',
#  'PHX',
#  'MEX',
#  'KUL',
#  'IAH',
#  'DOH',
#  'MNL',
#  'TFU',
#  'YYZ',
#  'CKG',
#  'JED',
#  'SHA',
#  'KMG',
#  'XIY',
#  'GRU',
#  'HGH',
#  'LGW',
#  'BOS',
#  'SGN']

# %%
browser.quit()
