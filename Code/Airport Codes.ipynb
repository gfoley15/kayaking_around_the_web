# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')

# %%
url = "https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic"
browser.visit(url)

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
table = soup.find('table', class_='wikitable sortable')

# %%
# Create an empty list
Airports = []
rows = table.find_all('tr', class_=False)
# Loop through the scraped data to create a list of rows
for row in rows:
    row_data_id = row.find_all('td')
    # Resource: StackOverflow provided code format for this part.
    row = [row.text for row in row_data_id]
    Airports.append(row)

# %%
Airports
# Out:
# [[],
#  ['1.',
#   ' Hartsfield–Jackson Atlanta International Airport',
#   'Atlanta, Georgia',
#   'United States',
#   'ATL/KATL',
#   '104,653,451',
#   '',
#   '11.7%\n'],
#  ['2.',
#   ' Dubai International Airport',
#   'Garhoud, Dubai, Dubai',
#   'United Arab Emirates',
#   'DXB/OMDB',
#   '86,994,365',
#   '3',
#   '31.7%\n'],
#  ['3.',
#   ' Dallas Fort Worth International Airport',
#   'Dallas–Fort Worth, Texas',
#   'United States',
#   'DFW/KDFW',
#   '81,755,538',
#   '1',
#   '11.4%\n'],
#  ['4.',
#   ' Heathrow Airport',
#   'Hillingdon, London',
#   'United Kingdom',
#   'LHR/EGLL',
#   '79,183,364',
#   '4',
#   '28.5%\n'],
#  ['5.',
#   ' Tokyo Haneda Airport',
#   'Ōta, Tokyo',
#   'Japan',
#   'HND/RJTT',
#   '78,719,302',
#   '11',
#   '55.1%\n'],
#  ['6.',
#   ' Denver International Airport',
#   'Denver, Colorado',
#   'United States',
#   'DEN/KDEN',
#   '77,837,917',
#   '3',
#   '12.3%\n'],
#  ['7.',
#   ' Istanbul Airport',
#   'Arnavutköy, Istanbul',
#   'Turkey',
#   'IST/LTFM',
#   '76,027,321',
#   '',
#   '18.3%\n'],
#  ['8.',
#   ' Los Angeles International Airport',
#   'Los Angeles, California',
#   'United States',
#   'LAX/KLAX',
#   '75,050,875',
#   '2',
#   '13.8%\n'],
#  ['9.',
#   " O'Hare International Airport",
#   'Chicago, Illinois',
#   'United States',
#   'ORD/KORD',
#   '73,894,226',
#   '5',
#   '8.1%\n'],
#  ['10.',
#   ' Indira Gandhi International Airport',
#   'Palam, Delhi',
#   'India',
#   'DEL/VIDP',
#   '72,214,841',
#   '1',
#   '21.4%\n'],
#  ['11.',
#   ' Charles de Gaulle Airport',
#   'Roissy-en-France, Île-de-France',
#   'France',
#   'CDG/LFPG',
#   '67,421,316',
#   '1',
#   '17.3%\n'],
#  ['12.',
#   ' Guangzhou Baiyun International Airport',
#   'Baiyun-Huadu, Guangzhou, Guangdong',
#   'China',
#   'CAN/ZGGG',
#   '63,169,169',
#   '?',
#   '142.0%\n'],
#  ['13.',
#   ' John F. Kennedy International Airport',
#   'Queens, New York, New York',
#   'United States',
#   'JFK/KJFK',
#   '62,464,331',
#   '2',
#   '13.0%\n'],
#  ['14.',
#   ' Amsterdam Airport Schiphol',
#   'Haarlemmermeer, North Holland',
#   'Netherlands',
#   'AMS/EHAM',
#   '61,889,586',
#   '1',
#   '18.0\n'],
#  ['15.',
#   ' Adolfo Suárez Madrid–Barajas Airport',
#   'Madrid',
#   'Spain',
#   'MAD/LEMD',
#   '60,181,604',
#   '',
#   '18.9%\n'],
#  ['16.',
#   ' Frankfurt Airport',
#   'Frankfurt, Hesse',
#   'Germany',
#   'FRA/EDDF',
#   '59,355,389',
#   '2',
#   '21.3%\n'],
#  ['17.',
#   ' Singapore Changi Airport',
#   'Changi, East Region',
#   'Singapore',
#   'SIN/WSSS',
#   '58,946,000',
#   '19',
#   '83.1%\n'],
#  ['18.',
#   ' Orlando International Airport',
#   'Orlando, Florida',
#   'United States',
#   'MCO/KMCO',
#   '57,735,726',
#   '1',
#   '15.1%\n'],
#  ['19.',
#   ' Harry Reid International Airport',
#   'Las Vegas, Nevada',
#   'United States',
#   'LAS/KLAS',
#   '57,666,456',
#   '7',
#   '9.4%\n'],
#  ['20.',
#   ' Seoul Incheon International Airport',
#   'Incheon',
#   'South Korea',
#   'ICN/RKSI',
#   '56,235,412',
#   '?',
#   '213.8%\n'],
#  ['21.',
#   ' Shanghai Pudong International Airport',
#   'Pudong, Shanghai',
#   'China',
#   'PVG/ZSPD',
#   '54,476,397',
#   '?',
#   '284.2%\n'],
#  ['22.',
#   ' Charlotte Douglas International Airport',
#   'Charlotte, North Carolina',
#   'United States',
#   'CLT/KCLT',
#   '53,445,770',
#   '3',
#   '11.9%\n'],
#  ['23.',
#   ' Beijing Capital International Airport',
#   'Chaoyang-Shunyi, Beijing',
#   'China',
#   'PEK/ZBAA',
#   '52,879,156',
#   '?',
#   '316.2%\n'],
#  ['24.',
#   " Shenzhen Bao'an International Airport",
#   "Bao'an, Shenzhen, Guangdong",
#   'China',
#   'SZX/ZGSZ',
#   '52,734,934',
#   '?',
#   '144.6%\n'],
#  ['25.',
#   ' Miami International Airport',
#   'Miami-Dade County, Florida',
#   'United States',
#   'MIA/KMIA',
#   '52,340,934',
#   '11',
#   '3.3%\n'],
#  ['26.',
#   ' Suvarnabhumi Airport',
#   'Racha Thewa, Bangkok metro',
#   'Thailand',
#   'BKK/VTBS',
#   '51,699,104',
#   '24',
#   '79.8%\n'],
#  ['27.',
#   ' Chhatrapati Shivaji Maharaj International Airport',
#   'Santacruz-Sahar, Mumbai, Maharashtra',
#   'India',
#   'BOM/VABB',
#   '51,589,040',
#   '1',
#   '34.6%\n'],
#  ['28.',
#   ' Seattle–Tacoma International Airport',
#   'SeaTac, Washington',
#   'United States',
#   'SEA/KSEA',
#   '50,877,260',
#   '7',
#   '10.7%\n'],
#  ['29.',
#   ' San Francisco International Airport',
#   'San Mateo County, California',
#   'United States',
#   'SFO/KSFO',
#   '50,196,094',
#   '5',
#   '18.7%\n'],
#  ['30.',
#   ' Josep Tarradellas Barcelona–El Prat Airport',
#   'Barcelona',
#   'Spain',
#   'BCN/LEBL',
#   '49,883,928',
#   '5',
#   '19.9%\n'],
#  ['31.',
#   ' Newark Liberty International Airport',
#   'Newark, New Jersey',
#   'United States',
#   'EWR/KEWR',
#   '49,084,774',
#   '8',
#   '12.7%\n'],
#  ['32.',
#   ' Soekarno–Hatta International Airport',
#   'Tangerang, Banten',
#   'Indonesia',
#   'CGK/WIII',
#   '49,080,532',
#   '5',
#   '23.9%\n'],
#  ['33.',
#   ' Phoenix Sky Harbor International Airport',
#   'Phoenix, Arizona',
#   'United States',
#   'PHX/KPHX',
#   '48,654,432',
#   '11',
#   '9.6%\n'],
#  ['34.',
#   ' Mexico City International Airport',
#   'Venustiano Carranza, Mexico City',
#   'Mexico',
#   'MEX/MMMX',
#   '48,416,008',
#   '14',
#   '4.7%\n'],
#  ['35.',
#   ' Kuala Lumpur International Airport',
#   'Sepang, Selangor',
#   'Malaysia',
#   'KUL/WMKK',
#   '47,242,468',
#   '?',
#   '86.0%\n'],
#  ['36.',
#   ' George Bush Intercontinental Airport',
#   'Houston, Texas',
#   'United States',
#   'IAH/KIAH',
#   '46,168,662',
#   '10',
#   '12.7%\n'],
#  ['37.',
#   ' Hamad International Airport',
#   'Doha',
#   'Qatar',
#   'DOH/OTHH',
#   '45,916,098',
#   '6',
#   '28.5%\n'],
#  ['38.',
#   ' Ninoy Aquino International Airport',
#   'Pasay/Parañaque, Metro Manila',
#   'Philippines',
#   'MNL/RPLL',
#   '45,300,322',
#   '6',
#   '46.7%\n'],
#  ['39.',
#   ' Chengdu Tianfu International Airport',
#   'Jianyang, Chengdu, Sichuan',
#   'China',
#   'TFU/ZUTF',
#   '44,786,032',
#   '?',
#   '237.4%\n'],
#  ['40.',
#   ' Toronto Pearson International Airport',
#   'Mississauga, Ontario',
#   'Canada',
#   'YYZ/CYYZ',
#   '44,761,805',
#   '11',
#   '23.1%\n'],
#  ['41.',
#   ' Chongqing Jiangbei International Airport',
#   'Chongqing',
#   'China',
#   'CKG/ZUCK',
#   '44,657,268',
#   '?',
#   '106.1%\n'],
#  ['42.',
#   ' King Abdulaziz International Airport',
#   'Jeddah',
#   'Saudi Arabia',
#   'JED/OEJN',
#   '42,910,407',
#   '4',
#   '35.7%\n'],
#  ['43.',
#   ' Shanghai Hongqiao International Airport',
#   'Shanghai',
#   'China',
#   'SHA/ZSSS',
#   '42,492,745',
#   '?',
#   '188.8%\n'],
#  ['44.',
#   ' Kunming Changshui International Airport',
#   'Kunming, Yunnan',
#   'China',
#   'KMG/ZPPP',
#   '42,053,214',
#   '?',
#   '97.4%\n'],
#  ['45.',
#   " Xi'an Xianyang International Airport",
#   "Xi'an, Shaanxi",
#   'China',
#   'XIY/ZLXY',
#   '41,371,228',
#   '?',
#   '205.1%\n'],
#  ['46.',
#   ' São Paulo/Guarulhos International Airport',
#   'São Paulo',
#   'Brazil',
#   'GRU/SBGR',
#   '41,307,919',
#   '?',
#   '19.8%\n'],
#  ['47.',
#   ' Hangzhou Xiaoshan International Airport',
#   'Hangzhou, Zhejiang',
#   'China',
#   'HGH/ZSHC',
#   '41,170,470',
#   '?',
#   '105.5%\n'],
#  ['48.',
#   ' Gatwick Airport',
#   'Crawley, West Sussex',
#   'United Kingdom',
#   'LGW/EGKK',
#   '40,905,856',
#   '13',
#   '24.5%\n'],
#  ['49.',
#   ' Logan International Airport',
#   'Boston, Massachusetts',
#   'United States',
#   'BOS/KBOS',
#   '40,861,658',
#   '19',
#   '13.2%\n'],
#  ['50.',
#   ' Tan Son Nhat International Airport',
#   'Ho Chi Minh City',
#   'Vietnam',
#   'SGN/VVTS',
#   '40,738,295',
#   '16',
#   '18.9%\n']]

# %%
Airports_df = pd.DataFrame(Airports, columns = ["Rank", "Airport", "Location", "Country", "A/P Code", "Total Passengers", "Rank Change", "Rank pct change"])

# %%
Airports_df = Airports_df.drop(columns=["Rank Change", "Rank pct change", (4, ICAO Airport)''], )

# %%
Airports_df[4, 'ICAO Airport'] = ""

# %%
Airports_df
# Out:
#     Rank                                            Airport  \
# 0   None                                               None
# 1     1.   Hartsfield–Jackson Atlanta International Airport
# 2     2.                        Dubai International Airport
# 3     3.            Dallas Fort Worth International Airport
# 4     4.                                   Heathrow Airport
# 5     5.                               Tokyo Haneda Airport
# 6     6.                       Denver International Airport
# 7     7.                                   Istanbul Airport
# 8     8.                  Los Angeles International Airport
# 9     9.                       O'Hare International Airport
# 10   10.                Indira Gandhi International Airport
# 11   11.                          Charles de Gaulle Airport
# 12   12.             Guangzhou Baiyun International Airport
# 13   13.              John F. Kennedy International Airport
# 14   14.                         Amsterdam Airport Schiphol
# 15   15.               Adolfo Suárez Madrid–Barajas Airport
# 16   16.                                  Frankfurt Airport
# 17   17.                           Singapore Changi Airport
# 18   18.                      Orlando International Airport
# 19   19.                   Harry Reid International Airport
# 20   20.                Seoul Incheon International Airport
# 21   21.              Shanghai Pudong International Airport
# 22   22.            Charlotte Douglas International Airport
# 23   23.              Beijing Capital International Airport
# 24   24.              Shenzhen Bao'an International Airport
# 25   25.                        Miami International Airport
# 26   26.                               Suvarnabhumi Airport
# 27   27.   Chhatrapati Shivaji Maharaj International Air...
# 28   28.               Seattle–Tacoma International Airport
# 29   29.                San Francisco International Airport
# 30   30.        Josep Tarradellas Barcelona–El Prat Airport
# 31   31.               Newark Liberty International Airport
# 32   32.               Soekarno–Hatta International Airport
# 33   33.           Phoenix Sky Harbor International Airport
# 34   34.                  Mexico City International Airport
# 35   35.                 Kuala Lumpur International Airport
# 36   36.               George Bush Intercontinental Airport
# 37   37.                        Hamad International Airport
# 38   38.                 Ninoy Aquino International Airport
# 39   39.               Chengdu Tianfu International Airport
# 40   40.              Toronto Pearson International Airport
# 41   41.           Chongqing Jiangbei International Airport
# 42   42.               King Abdulaziz International Airport
# 43   43.            Shanghai Hongqiao International Airport
# 44   44.            Kunming Changshui International Airport
# 45   45.               Xi'an Xianyang International Airport
# 46   46.          São Paulo/Guarulhos International Airport
# 47   47.            Hangzhou Xiaoshan International Airport
# 48   48.                                    Gatwick Airport
# 49   49.                        Logan International Airport
# 50   50.                 Tan Son Nhat International Airport
#
#                                 Location               Country  A/P Code  \
# 0                                   None                  None      None
# 1                       Atlanta, Georgia         United States  ATL/KATL
# 2                  Garhoud, Dubai, Dubai  United Arab Emirates  DXB/OMDB
# 3               Dallas–Fort Worth, Texas         United States  DFW/KDFW
# 4                     Hillingdon, London        United Kingdom  LHR/EGLL
# 5                             Ōta, Tokyo                 Japan  HND/RJTT
# 6                       Denver, Colorado         United States  DEN/KDEN
# 7                   Arnavutköy, Istanbul                Turkey  IST/LTFM
# 8                Los Angeles, California         United States  LAX/KLAX
# 9                      Chicago, Illinois         United States  ORD/KORD
# 10                          Palam, Delhi                 India  DEL/VIDP
# 11       Roissy-en-France, Île-de-France                France  CDG/LFPG
# 12    Baiyun-Huadu, Guangzhou, Guangdong                 China  CAN/ZGGG
# 13            Queens, New York, New York         United States  JFK/KJFK
# 14         Haarlemmermeer, North Holland           Netherlands  AMS/EHAM
# 15                                Madrid                 Spain  MAD/LEMD
# 16                      Frankfurt, Hesse               Germany  FRA/EDDF
# 17                   Changi, East Region             Singapore  SIN/WSSS
# 18                      Orlando, Florida         United States  MCO/KMCO
# 19                     Las Vegas, Nevada         United States  LAS/KLAS
# 20                               Incheon           South Korea  ICN/RKSI
# 21                      Pudong, Shanghai                 China  PVG/ZSPD
# 22             Charlotte, North Carolina         United States  CLT/KCLT
# 23              Chaoyang-Shunyi, Beijing                 China  PEK/ZBAA
# 24           Bao'an, Shenzhen, Guangdong                 China  SZX/ZGSZ
# 25            Miami-Dade County, Florida         United States  MIA/KMIA
# 26            Racha Thewa, Bangkok metro              Thailand  BKK/VTBS
# 27  Santacruz-Sahar, Mumbai, Maharashtra                 India  BOM/VABB
# 28                    SeaTac, Washington         United States  SEA/KSEA
# 29          San Mateo County, California         United States  SFO/KSFO
# 30                             Barcelona                 Spain  BCN/LEBL
# 31                    Newark, New Jersey         United States  EWR/KEWR
# 32                     Tangerang, Banten             Indonesia  CGK/WIII
# 33                      Phoenix, Arizona         United States  PHX/KPHX
# 34      Venustiano Carranza, Mexico City                Mexico  MEX/MMMX
# 35                      Sepang, Selangor              Malaysia  KUL/WMKK
# 36                        Houston, Texas         United States  IAH/KIAH
# 37                                  Doha                 Qatar  DOH/OTHH
# 38         Pasay/Parañaque, Metro Manila           Philippines  MNL/RPLL
# 39            Jianyang, Chengdu, Sichuan                 China  TFU/ZUTF
# 40                  Mississauga, Ontario                Canada  YYZ/CYYZ
# 41                             Chongqing                 China  CKG/ZUCK
# 42                                Jeddah          Saudi Arabia  JED/OEJN
# 43                              Shanghai                 China  SHA/ZSSS
# 44                       Kunming, Yunnan                 China  KMG/ZPPP
# 45                        Xi'an, Shaanxi                 China  XIY/ZLXY
# 46                             São Paulo                Brazil  GRU/SBGR
# 47                    Hangzhou, Zhejiang                 China  HGH/ZSHC
# 48                  Crawley, West Sussex        United Kingdom  LGW/EGKK
# 49                 Boston, Massachusetts         United States  BOS/KBOS
# 50                      Ho Chi Minh City               Vietnam  SGN/VVTS
#
#    Total Passengers ICAO Airport (4, ICAO Airport)
# 0              None
# 1       104,653,451
# 2        86,994,365
# 3        81,755,538
# 4        79,183,364
# 5        78,719,302
# 6        77,837,917
# 7        76,027,321
# 8        75,050,875
# 9        73,894,226
# 10       72,214,841
# 11       67,421,316
# 12       63,169,169
# 13       62,464,331
# 14       61,889,586
# 15       60,181,604
# 16       59,355,389
# 17       58,946,000
# 18       57,735,726
# 19       57,666,456
# 20       56,235,412
# 21       54,476,397
# 22       53,445,770
# 23       52,879,156
# 24       52,734,934
# 25       52,340,934
# 26       51,699,104
# 27       51,589,040
# 28       50,877,260
# 29       50,196,094
# 30       49,883,928
# 31       49,084,774
# 32       49,080,532
# 33       48,654,432
# 34       48,416,008
# 35       47,242,468
# 36       46,168,662
# 37       45,916,098
# 38       45,300,322
# 39       44,786,032
# 40       44,761,805
# 41       44,657,268
# 42       42,910,407
# 43       42,492,745
# 44       42,053,214
# 45       41,371,228
# 46       41,307,919
# 47       41,170,470
# 48       40,905,856
# 49       40,861,658
# 50       40,738,295
