# %%
# Import dependencies
import requests
from pymongo import MongoClient
import time
import json
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# assign the met database to a variable name
db = mongo['kayak']

# assign the collection to a variable
flight_search = db['flight_search']

# %%
flight_search = list(flight_search.find({}))

# %%
flight_search_df = pd.DataFrame(flight_search)
flight_search_df
# Out:
#                          _id  trip_id outbound_date return_date  \
# 0   6661d72035d7fd5611b1b1aa        0    2024-06-07  2024-06-10
# 1   6661d72035d7fd5611b1b1ab        1    2024-06-07  2024-06-10
# 2   6661d72035d7fd5611b1b1ac        2    2024-06-07  2024-06-10
# 3   6661d72035d7fd5611b1b1ad        3    2024-06-07  2024-06-10
# 4   6661d72035d7fd5611b1b1ae        4    2024-06-07  2024-06-10
# ..                       ...      ...           ...         ...
# 72  6661d72035d7fd5611b1b1f2       10    2024-06-07  2024-06-10
# 73  6661d72035d7fd5611b1b1f3       11    2024-06-07  2024-06-10
# 74  6661d72035d7fd5611b1b1f4       12    2024-06-07  2024-06-10
# 75  6661d72035d7fd5611b1b1f5       13    2024-06-07  2024-06-10
# 76  6661d72035d7fd5611b1b1f6       14    2024-06-07  2024-06-10
#
#    outbound_departure_time outbound_arrival_time outbound_flight_duration  \
# 0                  8:55 pm              10:25 pm                   3h 30m
# 1                  8:55 pm              10:25 pm                   3h 30m
# 2                  6:10 pm              10:43 pm                   6h 33m
# 3                  8:55 pm              10:25 pm                   3h 30m
# 4                  3:11 pm               4:40 pm                   3h 29m
# ..                     ...                   ...                      ...
# 72                 8:00 am               1:06 pm                   5h 06m
# 73                 4:23 pm              11:01 pm                   6h 38m
# 74                 5:57 pm              11:01 pm                   5h 04m
# 75                12:45 pm               6:07 pm                   5h 22m
# 76                 3:12 pm               8:21 pm                   5h 09m
#
#    outbound_route   outbound_airline return_departure_time  \
# 0         MCI-LAX    Spirit Airlines               2:53 pm
# 1         MCI-LAX    Spirit Airlines              10:54 pm
# 2         MCI-LAX    Sun Country Air               2:53 pm
# 3         MCI-LAX    Spirit Airlines               8:39 am
# 4         MCI-LAX              Delta               9:01 am
# ..            ...                ...                   ...
# 72        MCI-HSV    United Airlines              11:05 am
# 73        MCI-HSV  American Airlines               4:43 pm
# 74        MCI-HSV  American Airlines               9:33 am
# 75        MCI-HSV    United Airlines              11:05 am
# 76        MCI-HSV    United Airlines              11:05 am
#
#    return_arrival_time return_flight_duration return_route     return_airline  \
# 0              8:04 pm                 3h 11m      LAX-MCI    Spirit Airlines
# 1            6:09 am+1                 5h 15m      LAX-MCI    Spirit Airlines
# 2              8:04 pm                 3h 11m      LAX-MCI    Spirit Airlines
# 3              5:17 pm                 6h 38m      LAX-MCI    Sun Country Air
# 4              2:16 pm                 3h 15m      LAX-MCI              Delta
# ..                 ...                    ...          ...                ...
# 72             4:35 pm                 5h 30m      HSV-MCI    United Airlines
# 73            10:57 pm                 6h 14m      HSV-MCI  American Airlines
# 74             3:08 pm                 5h 35m      HSV-MCI  American Airlines
# 75             4:35 pm                 5h 30m      HSV-MCI    United Airlines
# 76             4:35 pm                 5h 30m      HSV-MCI    United Airlines
#
#    price           tier
# 0   $372        Economy
# 1   $404        Economy
# 2   $444        Economy
# 3   $463        Economy
# 4   $867  Basic Economy
# ..   ...            ...
# 72  $788        Economy
# 73  $310  Basic Economy
# 74  $834     Main Cabin
# 75  $795        Economy
# 76  $837        Economy
#
# [77 rows x 16 columns]

# %%
flight_search_df.to_csv('flight_search.csv',index=False) # export for collaboration purposes
